# %%
# Install
# !pip install ultralytics

# %%
# Import
from ultralytics import YOLO

# %%
# Load Model
model = YOLO("yolov8n.pt")

# %%
# Train
model.train(
    data="data/data.yaml",
    epochs=20,
    imgsz=640
)
